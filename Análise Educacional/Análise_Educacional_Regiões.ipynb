# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('regiao.csv')
df
# Out:
#       ano        regiao      rede       ensino  anos_escolares  \
# 0    2005  Centro-Oeste  estadual  fundamental    finais (6-9)
# 1    2005  Centro-Oeste  estadual  fundamental  iniciais (1-5)
# 2    2005  Centro-Oeste  estadual        medio     todos (1-4)
# 3    2005  Centro-Oeste   privada  fundamental    finais (6-9)
# 4    2005  Centro-Oeste   privada  fundamental  iniciais (1-5)
# ..    ...           ...       ...          ...             ...
# 490  2021           Sul   privada        medio     todos (1-4)
# 491  2021           Sul  estadual        medio     todos (1-4)
# 492  2021  Centro-Oeste     total        medio     todos (1-4)
# 493  2021  Centro-Oeste   privada        medio     todos (1-4)
# 494  2021  Centro-Oeste  estadual        medio     todos (1-4)
#
#      taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0              72.1              0.721828                233.50
# 1              83.0              0.837081                185.38
# ...

# %%
df['regiao'].unique()
# Out:
# array(['Centro-Oeste', 'Nordeste', 'Norte', 'Sudeste', 'Sul'],
#       dtype=object)

# %%
df['rede'].unique()
# Out:
# array(['estadual', 'privada', 'publica', 'total'], dtype=object)

# %%
df['ensino'].unique()
# Out:
# array(['fundamental', 'medio'], dtype=object)

# %%
df['anos_escolares'].unique()
# Out:
# array(['finais (6-9)', 'iniciais (1-5)', 'todos (1-4)'], dtype=object)

# %%
df['taxa_aprovacao'].unique()
# Out:
# array([72.1, 83. , 68. , 94.4, 97.3, 92.4, 72.8, 82.1, 75.2, 83.8, 71.5,
#        66.8, 73.8, 68.2, 92.2, 96. , 90.8, 67.1, 70.8, 69.3, 73.1, 70.9,
#        75.3, 77.5, 68.8, 95.1, 96.7, 92. , 74.1, 70.6, 71.8, 70.5, 73.2,
#        95.4, 98. , 93.6, 81.8, 89.4, 83.5, 90.5, 76.1, 86.3, 69.1, 96.1,
#        97.5, 94.2, 77.2, 87. , 78.8, 87.8, 72.3, 77. , 88.1, 69.9, 97.9,
#        93. , 78.4, 80.4, 89. , 73. , 69. , 69.6, 93.2, 96.5, 92.5, 71. ,
#        77.8, 72.6, 79.2, 71.6, 76. , 79.6, 68.4, 95.3, 96.9, 75.9, 77.1,
#        83.1, 93.3, 95.7, 98.4, 83.2, 91.1, 84.8, 92.1, 76.3, 80.5, 73.6,
#        98.1, 94.7, 81.1, 90.3, 82.2, 91. , 80.8, 94.6, 98.3, 92.6, 81.6,
#        89.7, 83.3, 90.9, 70.7, 73.5, 81.9, 75.5, 83.6, 74.3, 77.9, 85.7,
#        97.1, 94. , 78.2, 80.1, 81. , 84.9, 95.8, 95. , 93.5, 84.1, 85.5,
#        80.6, 98.2, 94.3, 91.9, 76.7, 82.9, 91.8, 72.4, 98.6, 91.7, 85.3,
#        92.8, 75.6, 72.9, 74.2, 97. , 92.9, 75.7, 85.8, 77.7, 87.5, 89.6,
# ...

# %%
df['projecao'].unique()
# Out:
# array([nan, 3.2, 3.9, 2.9, 5.5, 5.9, 5.8, 3.8, 3.5, 4.1, 3.4, 2.7, 3. ,
#        5.4, 5.2, 2.6, 3.1, 3.3, 5.6, 5.1, 3.7, 4.6, 6.1, 6.3, 5.7, 4.4,
#        4. , 3.6, 4.3, 6.2, 4.5, 4.2, 2.8, 5.3, 4.9, 6.6, 4.8, 5. , 6.5,
#        6. , 4.7, 6.9, 6.4, 6.8, 7.1, 6.7, 7. , 7.3, 7.2, 7.4, 7.6, 7.5])

# %%
df['projecao'].isnull().sum()
# Out:
# 110

# %%
df.describe()
# Out:
#                ano  taxa_aprovacao  indicador_rendimento  \
# count   495.000000      495.000000            495.000000
# mean   2013.000000       87.971515              0.885319
# std       5.169202        8.653254              0.078978
# min    2005.000000       66.800000              0.668975
# 25%    2009.000000       81.250000              0.818830
# 50%    2013.000000       90.300000              0.903670
# 75%    2017.000000       95.350000              0.952799
# max    2021.000000       99.400000              0.994000
#
#        nota_saeb_matematica  nota_saeb_lingua_portuguesa  \
# count            495.000000                   495.000000
# mean             250.558990                   241.746323
# std               38.182906                    38.905287
# min              156.410000                   149.600000
# 25%              225.725000                   215.425000
# 50%              249.860000                   244.940000
# ...

# %%
mediaTA_regiao = df.groupby('regiao')['taxa_aprovacao'].mean()
mediaTA_regiao
# Out:
# regiao
# Centro-Oeste    88.952525
# Nordeste        84.970707
# Norte           85.822222
# Sudeste         91.243434
# Sul             88.868687
# Name: taxa_aprovacao, dtype: float64

# %%
mediaTA_regiao.plot(kind = 'bar', color = 'lightblue')
mediaTA_regiao.sort_values(inplace = True)

plt.title('Média Geral da Taxa de Aprovação por Região')
plt.xlabel('Região')
plt.ylabel('Média')
plt.ylim(80, 95)
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos iniciais para cada tipo de ensino - Região Nordeste

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Nordeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    84.288889
# privada     97.422222
# publica     85.800000
# total       87.311111
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Nordeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'red')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Nordeste para os Anos Iniciais (1-5) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF1-Nordeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos iniciais para cada tipo de ensino - Região Norte

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Norte'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    88.266667
# privada     97.955556
# publica     84.733333
# total       85.544444
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Norte'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'green')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Norte para os Anos Iniciais (1-5) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF1-Norte.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos iniciais para cada tipo de ensino - Região Sul

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Sul'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    92.144444
# privada     98.511111
# publica     92.922222
# total       93.544444
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Sul'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'purple')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sul para os Anos Iniciais (1-5) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF1-Sul.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos iniciais para cada tipo de ensino - Região Centro-Oeste

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Centro-Oeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    92.044444
# privada     98.666667
# publica     91.777778
# total       92.755556
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Centro-Oeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'orange')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Centro-Oeste para os Anos Iniciais (1-5) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF1-Centro-Oeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos iniciais para cada tipo de ensino - Região Sudeste

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Sudeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    96.922222
# privada     98.344444
# publica     94.300000
# total       94.944444
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'iniciais (1-5)'
media_iniciais = df[df['anos_escolares'] == 'iniciais (1-5)']

# Filtrar para a região 'Sudeste'
media_iniciais_nordeste = media_iniciais[media_iniciais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_iniciais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'yellow')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sudeste para os Anos Iniciais (1-5) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF1-Sudeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos finais para cada tipo de ensino - Região Nordeste

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Nordeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    76.366667
# privada     94.500000
# publica     78.288889
# total       80.088889
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Nordeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'red')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Nordeste para os Anos Finais (6-9) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF-Nordeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos finais para cada tipo de ensino - Região Norte

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Norte'
media_finais_norte = media_finais[media_finais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeNorte = media_finais_norte.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_redeNorte
# Out:
# rede
# estadual    82.133333
# privada     96.022222
# publica     81.533333
# total       82.488889
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Norte'
media_finais_norte = media_finais[media_finais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeNorte = media_finais_norte.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_redeNorte = mediaTA_por_redeNorte.sort_values()

# Criar um gráfico de barras
mediaTA_por_redeNorte.plot(kind = 'bar', figsize = (10, 6), color = 'green')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Norte para os Anos Finais (6-9) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF-Norte.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos finais para cada tipo de ensino - Região Sul

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Sul'
media_finais_sul = media_finais[media_finais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeSul = media_finais_sul.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_redeSul
# Out:
# rede
# estadual    83.477778
# privada     96.544444
# publica     83.922222
# total       85.155556
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Sul'
media_finais_sul = media_finais[media_finais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeSul = media_finais_sul.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_redeSul = mediaTA_por_redeSul.sort_values()

# Criar um gráfico de barras
mediaTA_por_redeSul.plot(kind = 'bar', figsize = (10, 6), color = 'purple')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sul para os Anos Finais (6-9) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF-Sul.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos finais para cada tipo de ensino - Região Centro-Oeste

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Centro-Oeste'
media_finais_CentroOeste = media_finais[media_finais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeCentroOeste = media_finais_CentroOeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_redeCentroOeste
# Out:
# rede
# estadual    85.100000
# privada     96.166667
# publica     85.477778
# total       86.922222
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Centro-Oeste'
media_finais_CentroOeste = media_finais[media_finais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeCentroOeste = media_finais_sul.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_redeCentroOeste = mediaTA_por_redeCentroOeste.sort_values()

# Criar um gráfico de barras
mediaTA_por_redeCentroOeste.plot(kind = 'bar', figsize = (10, 6), color = 'orange')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Centro-Oeste para os Anos Finais (6-9) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF-CentroOeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos anos finais para cada tipo de ensino - Região Sudeste

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Sudeste'
media_finais_Sudeste = media_finais[media_finais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeSudeste = media_finais_Sudeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_redeSudeste
# Out:
# rede
# estadual    88.355556
# privada     95.977778
# publica     87.800000
# total       89.000000
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'finais (6-9)'
media_finais = df[df['anos_escolares'] == 'finais (6-9)']

# Filtrar para a região 'Sudeste'
media_finais_Sudeste = media_finais[media_finais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_redeSudeste = media_finais_sul.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_redeSudeste = mediaTA_por_redeCentroOeste.sort_values()

# Criar um gráfico de barras
mediaTA_por_redeSudeste.plot(kind = 'bar', figsize = (10, 6), color = 'yellow')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sudeste para os Anos Finais (6-9) do fundamental')
plt.ylim(70, 100)
plt.savefig('EF-Sudeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos Ensino Médio para cada tipo de ensino - Região Nordeste

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Nordeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    77.522222
# privada     93.844444
# total       79.244444
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Nordeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Nordeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'red')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Nordeste para o Ensino Médio')
plt.ylim(70, 100)
plt.savefig('EM-Nordeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos Ensino Médio para cada tipo de ensino - Região Norte

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Norte'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    74.600000
# privada     94.688889
# total       76.077778
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Norte'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Norte']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'green')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Norte para o Ensino Médio')
plt.ylim(70, 100)
plt.savefig('EM-Norte.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos Ensino Médio para cada tipo de ensino - Região Sul

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Sul'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    76.822222
# privada     95.322222
# total       79.188889
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Sul'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Sul']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'purple')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sul para o Ensino Médio')
plt.ylim(70, 100)
plt.savefig('EM-Sul.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos Ensino Médio para cada tipo de ensino - Região Centro-Oeste

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Centro-Oeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    76.100000
# privada     94.622222
# total       78.844444
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Centro-Oeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Centro-Oeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'orange')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Centro-Oeste para o Ensino Médio')
plt.ylim(70, 100)
plt.savefig('EM-CentroOeste.png')
plt.show()

# %% [markdown]
# # Taxa de aprovação dos Ensino Médio para cada tipo de ensino - Região Sudeste

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Sudeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()
mediaTA_por_rede
# Out:
# rede
# estadual    80.511111
# privada     94.933333
# total       82.588889
# Name: taxa_aprovacao, dtype: float64

# %%
# Filtrar os dados para 'todos (1-4)'
media_finais = df[df['anos_escolares'] == 'todos (1-4)']

# Filtrar para a região 'Sudeste'
media_finais_nordeste = media_finais[media_finais['regiao'] == 'Sudeste']

# Calcular a média da 'taxa_aprovacao' por 'rede'
mediaTA_por_rede = media_finais_nordeste.groupby('rede')['taxa_aprovacao'].mean()

# Ordenar os valores
mediaTA_por_rede = mediaTA_por_rede.sort_values()

# Criar um gráfico de barras
mediaTA_por_rede.plot(kind = 'bar', figsize = (10, 6), color = 'yellow')

plt.xlabel('Rede de Ensino')
plt.ylabel('Média da Taxa de Aprovação')
plt.title('Taxa de Aprovação por Rede de Ensino na Região Sudeste para o Ensino Médio')
plt.ylim(70, 100)
plt.savefig('EM-Sudeste.png')
plt.show()

# %% [markdown]
# # Análise de Tendências ao Longo do Tempo

# %%
metrica = 'taxa_aprovacao'

df_tendencia = df.groupby('ano')[metrica].mean()


plt.figure(figsize=(10, 6))
plt.plot(df_tendencia.index, df_tendencia.values, marker='o')
plt.title('Tendência da Taxa de Aprovação ao longo do tempo')
plt.xlabel('Ano')
plt.ylabel('Taxa de Aprovação')
plt.grid(True)
plt.savefig('Tendência_Aprovação.png')
plt.show()

# %%
metrica = 'indicador_rendimento'

df_tendencia = df.groupby('ano')[metrica].mean()


plt.figure(figsize=(10, 6))
plt.plot(df_tendencia.index, df_tendencia.values, marker='o', color = 'orange')
plt.title('Tendência do Rendimento Escolar ao longo do tempo')
plt.xlabel('Ano')
plt.ylabel('Indicador do Rendimento Escolar')
plt.grid(True)
plt.savefig('Tendência_RendEscolar.png')
plt.show()

# %% [markdown]
# # Progressão das notas em Matemática e Português ao longo do tempo na rede pública de Ensino Educacional

# %%
df_publica = df[df['rede'] == 'publica']

df_media = df_publica.groupby(['ano', 'regiao'])['nota_saeb_matematica'].mean().reset_index()

regioes = df_media['regiao'].unique()

plt.figure(figsize = (10, 8))

for regiao in regioes:
    df_regiao = df_media[df_media['regiao'] == regiao]
    plt.plot(df_regiao['ano'], df_regiao['nota_saeb_matematica'], label = regiao)

plt.xlabel('Ano')
plt.ylabel('Média da Nota de Matemática')
plt.title('Progressão da Nota de Matemática ao longo do tempo na rede pública para cada região')
plt.legend()
plt.savefig('Pública-Progressão_Matemática.png')
plt.show()

# %%
df_publica = df[df['rede'] == 'publica']

df_media = df_publica.groupby(['ano', 'regiao'])['nota_saeb_lingua_portuguesa'].mean().reset_index()

regioes = df_media['regiao'].unique()

plt.figure(figsize = (10, 8))

for regiao in regioes:
    df_regiao = df_media[df_media['regiao'] == regiao]
    plt.plot(df_regiao['ano'], df_regiao['nota_saeb_lingua_portuguesa'], label = regiao)

plt.xlabel('Ano')
plt.ylabel('Média da Nota de Matemática')
plt.title('Progressão da Nota de Língua Portuguesa ao longo do tempo na rede pública para cada região')
plt.legend()
plt.savefig('Pública-Progressão_Português.png')
plt.show()

# %% [markdown]
# # Progressão das notas em Matemática e Português ao longo do tempo na rede particular de Ensino Educacional

# %%
df_publica = df[df['rede'] == 'privada']

df_media = df_publica.groupby(['ano', 'regiao'])['nota_saeb_matematica'].mean().reset_index()

regioes = df_media['regiao'].unique()

plt.figure(figsize = (10, 8))

for regiao in regioes:
    df_regiao = df_media[df_media['regiao'] == regiao]
    plt.plot(df_regiao['ano'], df_regiao['nota_saeb_matematica'], label = regiao)

plt.xlabel('Ano')
plt.ylabel('Média da Nota de Matemática')
plt.title('Progressão da Nota de Matemática ao longo do tempo na rede privada para cada região')
plt.legend()
plt.savefig('Privada-Progressão_Matemática.png')
plt.show()

# %%
df_publica = df[df['rede'] == 'privada']

df_media = df_publica.groupby(['ano', 'regiao'])['nota_saeb_lingua_portuguesa'].mean().reset_index()

regioes = df_media['regiao'].unique()

plt.figure(figsize = (10, 8))

for regiao in regioes:
    df_regiao = df_media[df_media['regiao'] == regiao]
    plt.plot(df_regiao['ano'], df_regiao['nota_saeb_lingua_portuguesa'], label = regiao)

plt.xlabel('Ano')
plt.ylabel('Média da Nota de Matemática')
plt.title('Progressão da Nota de Língua Portuguesa ao longo do tempo na rede privada para cada região')
plt.legend()
plt.savefig('Privada-Progressão_Português.png')
plt.show()
